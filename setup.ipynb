# %%
pip install streamlit
# Out:
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached pyarrow-19.0.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------------------ --------------------- 4.5/9.8 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 23.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 10.0 MB/s eta 0:00:00
# ...
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
# Using cached pyarrow-19.0.1-cp311-cp311-win_amd64.whl (25.3 MB)
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------------------------ --- 6.3/6.9 MB 32.2 MB/s eta 0:00:01
# ...
